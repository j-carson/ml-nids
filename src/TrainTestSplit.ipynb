# %% [markdown]
# # Train Test Split

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
# %load_ext watermark
# %watermark -iv
# Out:
# pandas 0.24.0

# %%
# %load_ext sql
# %config SqlMagic.autopandas = True

# %%
# %sql postgres://localhost/nb15
# Out:
# 'Connected: @nb15'

# %%
# %%sql
# CREATE TABLE shuffle_split  (
#     link_index INTEGER,
#     train_set BOOLEAN DEFAULT TRUE,
#     FOREIGN KEY (link_index) REFERENCES full_data (index)
# );
# Out:
#  * postgres://localhost/nb15
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# put everything in the test set, then take 40% out for 
# the test holdout

# %%
# %%sql
# INSERT INTO
#         shuffle_split(link_index)
# SELECT
#         index
# FROM
#         full_data;
# Out:
#  * postgres://localhost/nb15
# 2540044 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
attack_cats = %sql select distinct(attack_cat) cats from full_data;
attack_cats = list(attack_cats.cats)
# Out:
#  * postgres://localhost/nb15
# 10 rows affected.

# %%
attack_cats
# Out:
# ['shellcode',
#  'worms',
#  'normal',
#  'backdoors',
#  'dos',
#  'generic',
#  'exploits',
#  'fuzzers',
#  'analysis',
#  'reconnaissance']

# %%
test_size = .4

# %%
for cat in attack_cats:
    catrows = %sql select count(attack_cat) nrows from full_data where attack_cat = '{cat}'
    testrows = int(catrows.nrows * test_size)
    query_string = f"""
WITH
forty_percent AS (
    SELECT index 
    FROM full_data
    WHERE attack_cat = '{cat}'
    ORDER BY random()
    LIMIT {testrows}
)
UPDATE shuffle_split 
SET train_set = FALSE
WHERE link_index IN (SELECT index FROM forty_percent);
"""
    # %sql $query_string
# Out:
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 604 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 69 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 887504 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 931 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 6541 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 86192 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 17810 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 9698 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 1070 rows affected.
#  * postgres://localhost/nb15
# 1 rows affected.
#  * postgres://localhost/nb15
# 5594 rows affected.

# %%
# %%sql
# CREATE VIEW full_split
# AS
#     SELECT full_data.*, shuffle_split.train_set
#     FROM
#         full_data
#         INNER JOIN shuffle_split
#         ON full_data.index = shuffle_split.link_index;
# Out:
#  * postgres://localhost/nb15
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# SELECT attack_cat, train_set, COUNT(train_set)
# FROM full_split
# GROUP BY attack_cat, train_set
# ORDER BY attack_cat, count
# Out:
#  * postgres://localhost/nb15
# 20 rows affected.
#         attack_cat  train_set    count
# 0         analysis      False     1070
# 1         analysis       True     1607
# 2        backdoors      False      931
# 3        backdoors       True     1398
# 4              dos      False     6541
# 5              dos       True     9812
# 6         exploits      False    17810
# 7         exploits       True    26715
# 8          fuzzers      False     9698
# 9          fuzzers       True    14548
# 10         generic      False    86192
# 11         generic       True   129289
# 12          normal      False   887504
# 13          normal       True  1331257
# 14  reconnaissance      False     5594
# 15  reconnaissance       True     8393
# 16       shellcode      False      604
# 17       shellcode       True      907
# 18           worms      False       69
# 19           worms       True      105

# %%
# %%sql
# WITH split_query AS (
#     SELECT
#         attack_cat,
#         train_set,
#         proto,
#         cast(count(*) as float) split_count
#     FROM
#         full_split
#     WHERE
#         proto in ('tcp', 'udp')
#     GROUP BY
#         attack_cat, train_set, proto
# ),
# total_query AS (
#     SELECT
#         attack_cat,
#         proto,
#         cast(count(*) as float) proto_count
#     FROM
#         full_split
#     WHERE
#         proto in ('tcp', 'udp')
#     GROUP BY
#         attack_cat, proto
# )
# SELECT
#     split_query.attack_cat,
#     split_query.proto,
#     split_count,
#     proto_count,
#     split_query.train_set,
#     split_count/proto_count percent
# FROM
#     split_query
#     LEFT JOIN total_query
#         ON
#                 split_query.attack_cat = total_query.attack_cat
#         AND
#                 split_query.proto = total_query.proto
# ORDER BY
#     attack_cat, proto, train_set
# Out:
#  * postgres://localhost/nb15
# 38 rows affected.
#         attack_cat proto  split_count  proto_count  train_set   percent
# 0         analysis   tcp        237.0        622.0      False  0.381029
# 1         analysis   tcp        385.0        622.0       True  0.618971
# 2        backdoors   tcp        141.0        323.0      False  0.436533
# 3        backdoors   tcp        182.0        323.0       True  0.563467
# 4        backdoors   udp         15.0         34.0      False  0.441176
# 5        backdoors   udp         19.0         34.0       True  0.558824
# 6              dos   tcp       1350.0       3336.0      False  0.404676
# 7              dos   tcp       1986.0       3336.0       True  0.595324
# 8              dos   udp        231.0        527.0      False  0.438330
# 9              dos   udp        296.0        527.0       True  0.561670
# 10        exploits   tcp      10896.0      27443.0      False  0.397041
# 11        exploits   tcp      16547.0      27443.0       True  0.602959
# 12        exploits   udp        369.0        874.0      False  0.422197
# 13        exploits   udp        505.0        874.0       True  0.577803
# 14         fuzzers   tcp       6191.0      15474.0      False  0.400090
# 15         fuzzers   tcp       9283.0      15474.0       True  0.599910
# 16         fuzzers   udp       2420.0       6043.0      False  0.400463
# 17         fuzzers   udp       3623.0       6043.0       True  0.599537
# 18         generic   tcp       1249.0       3118.0      False  0.400577
# 19         generic   tcp       1869.0       3118.0       True  0.599423
# 20         generic   udp      84244.0     210600.0      False  0.400019
# 21         generic   udp     126356.0     210600.0       True  0.599981
# 22          normal   tcp     574362.0    1436887.0      False  0.399727
# 23          normal   tcp     862525.0    1436887.0       True  0.600273
# 24          normal   udp     307201.0     766685.0      False  0.400687
# 25          normal   udp     459484.0     766685.0       True  0.599313
# 26  reconnaissance   tcp       2795.0       6965.0      False  0.401292
# 27  reconnaissance   tcp       4170.0       6965.0       True  0.598708
# 28  reconnaissance   udp       1909.0       4890.0      False  0.390389
# 29  reconnaissance   udp       2981.0       4890.0       True  0.609611
# 30       shellcode   tcp        292.0        750.0      False  0.389333
# 31       shellcode   tcp        458.0        750.0       True  0.610667
# 32       shellcode   udp        312.0        761.0      False  0.409987
# 33       shellcode   udp        449.0        761.0       True  0.590013
# 34           worms   tcp         64.0        153.0      False  0.418301
# 35           worms   tcp         89.0        153.0       True  0.581699
# 36           worms   udp          5.0         21.0      False  0.238095
# 37           worms   udp         16.0         21.0       True  0.761905

# %% [markdown]
# I only split the data based on attack_category, not on the packet type, so these aren't all 60/40 but they all seem to be close enough.
